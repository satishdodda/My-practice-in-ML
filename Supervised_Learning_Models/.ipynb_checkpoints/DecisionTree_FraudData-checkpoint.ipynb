# %%
# 1. download libraries
# 2. get data
# 3. div.. into training and test data(not doing as of now)
# 4. check for any missin and outliers, add new var if required (not doing as of now)
# 5. do model building on cleaned data
# 6. calc acc of model- tree,model.fit,predict,accuracy

# %%
# 1. downloading libraries
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

#from sklearn.preprocessing import OneHotEncoder
#from sklearn import preprocessing

# %%
# 2. getting data
fraud_train = pd.read_csv("C:\\Users\\dvenk\\Practice in Python\\Supervised_Learning_Models\\Fraud_check.csv")

# %%
fraud_train
# Out:
#     Undergrad Marital.Status  Taxable.Income  City.Population  \
# 0          NO         Single           68833            50047
# 1         YES       Divorced           33700           134075
# 2          NO        Married           36925           160205
# 3         YES         Single           50190           193264
# 4          NO        Married           81002            27533
# ..        ...            ...             ...              ...
# 595       YES       Divorced           76340            39492
# 596       YES       Divorced           69967            55369
# 597        NO       Divorced           47334           154058
# 598       YES        Married           98592           180083
# 599        NO       Divorced           96519           158137
#
#      Work.Experience Urban
# 0                 10   YES
# 1                 18   YES
# 2                 30   YES
# 3                 15   YES
# 4                 28    NO
# ..               ...   ...
# ...

# %%
#setting the model 
model_class = DecisionTreeClassifier()
#model_regr = DecisionTreeRegressor()

# %%
fraud_train['Marital.Status'] = fraud_train['Marital.Status'].astype('category')
fraud_train = pd.get_dummies(fraud_train)

# %%
fraud_train['Urban'] = fraud_train['Urban'].astype('category')
fraud_train = pd.get_dummies(fraud_train)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Urban'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-22c16fde296d> in <module>
# ...

# %%
fraud_train['Undergrad'] = fraud_train['Undergrad'].astype('category')
fraud_train = pd.get_dummies(fraud_train)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Undergrad'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-c4f275ad7837> in <module>
# ...

# %%
fraud_train_x = fraud_train.drop(columns=['Taxable.Income'],axis=1)
fraud_train_y = fraud_train['Taxable.Income']

#model.fit(fraud_train_x, fraud_train_y)
#fraud_train_y

# %%
fraud_train
# Out:
#      Taxable.Income  City.Population  Work.Experience  Undergrad_NO  \
# 0             68833            50047               10             1
# 1             33700           134075               18             0
# 2             36925           160205               30             1
# 3             50190           193264               15             0
# 4             81002            27533               28             1
# ..              ...              ...              ...           ...
# 595           76340            39492                7             0
# 596           69967            55369                2             0
# 597           47334           154058                0             1
# 598           98592           180083               17             0
# 599           96519           158137               16             1
#
#      Undergrad_YES  Marital.Status_Divorced  Marital.Status_Married  \
# 0                0                        0                       0
# ...

# %%
# Out:
#      Taxable.Income  City.Population  Work.Experience  Undergrad_NO  \
# 0             68833            50047               10             1
# 1             33700           134075               18             0
# 2             36925           160205               30             1
# 3             50190           193264               15             0
# 4             81002            27533               28             1
# ..              ...              ...              ...           ...
# 595           76340            39492                7             0
# 596           69967            55369                2             0
# 597           47334           154058                0             1
# 598           98592           180083               17             0
# 599           96519           158137               16             1
#
#      Undergrad_YES  Marital.Status_Divorced  Marital.Status_Married  \
# 0                0                        0                       0
# ...
