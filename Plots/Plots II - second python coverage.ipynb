# %%
import matplotlib.pyplot as plt

import numpy as np

linear_data = np.array([1,2,3,4,5,6,7,8])

plt.plot(linear_data,color='r')#why this is giving blue colour
plt.plot(linear_data,color = 'g')#why green color is not coming + symbols also,how come blue curcles come from is that by defult?


plt.plot(linear_data,'-b')
plt.plot(linear_data,'-r')#why this is giving blue colour again

plt.plot(linear_data,'|b')
#plt.scatter(linear_data, linear_data, s=25,c='magenta')
plt.plot(linear_data,'*b')# | is wrkng, but where doo the star go?!!
plt.subplot(1, 1, 1)
# Out:
# <ipython-input-18-50b4fbafc072>:17: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(1, 1, 1)

# %%
exponential_data = linear_data**3
# subplot with 1 row, 2 columns, and current axis is 2nd subplot axes
plt.subplot(1,2,2)
plt.plot(linear_data, '-o')
plt.plot(exponential_data,'+g')

# %%
# plot exponential data on 1st subplot axes
plt.subplot(1, 2, 1)
plt.plot(exponential_data, '-x')

# %%
#ax1 = plt.subplot(1, 2, 1)
plt.plot(linear_data, '-o')
# pass sharey=ax1 to ensure the two subplots share the same y axis
#ax2 = plt.subplot(1, 2, 2, sharey=ax1)
plt.plot(exponential_data, '-x')

# %%
plt.figure()# why using figure everytime - x,y - number
# the right hand side is equivalent shorthand syntax
plt.subplot(1,2,1) == plt.subplot(121)
# Out:
# <ipython-input-72-279ae812cfbc>:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(1,2,1) == plt.subplot(121)
# True

# %%
# create a 3x3 grid of subplots
fig, ax = plt.subplots(4, 3, sharex=True, sharey=True)
# plot the linear_data on the 5th subplot axes 
ax[0][1].plot(linear_data, '8')
ax[3][2].plot(linear_data, '3')
ax[2][1].plot(linear_data, '2')
ax[0][0].plot(linear_data, '1')

# %%
# set inside tick labels to visible
for ax in plt.gcf().get_axes():
    for label in ax.get_xticklabels() + ax.get_yticklabels():
        label.set_visible(True)

# %%
# necessary on some systems to update the plot
plt.gcf().canvas.draw()

# %%
# Histograms
# create 2x2 grid of axis subplots
#fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex=True)
fig, ((ax1, ax2),(ax3, ax4)) = plt.subplots(2, 2, sharex=True)
axs = [ax1,ax2,ax3,ax4]

# draw n = 10, 100, 1000, and 10000 samples from the normal distribution and plot corresponding histograms
for n in range(0,len(axs)):
    sample_size = 10**(n+1)
    sample = np.random.normal(loc=0.0, scale=1.0, size=sample_size)
    axs[n].hist(sample)
    axs[n].set_title('n={}'.format(sample_size))

# %%
# repeat with number of bins set to 100
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex=True)
axs = [ax1,ax2,ax3,ax4]

for n in range(0,len(axs)):
    sample_size = 10**(n+1)
    sample = np.random.normal(loc=0.0, scale=1.0, size=sample_size)
    axs[n].hist(sample, bins=1000)
    axs[n].set_title('n={}'.format(sample_size))

# %%
plt.figure()


Y = np.random.normal(loc=0.0, scale=1.0, size=10)
X = np.random.random(size=10)
plt.subplot(1,2,2)
plt.scatter(X,Y)


Y=np.random.normal(size=10)
X=np.random.normal(size=10)
plt.subplot(1,2,1)
plt.scatter(X,Y)

# %%
a=np.random.random(size=14)
b= np.random.normal(size=14)
plt.subplot(1,2,1)
plt.scatter(a,b)

a1= np.random.normal(size=14)
b1= np.random.normal(size=14)
plt.subplot(1,2,2)
plt.scatter(a1,b1)
#plt.subplot(1,2,2)

# %%
# use gridspec to partition the figure into subplots
import matplotlib.gridspec as gridspec

plt.figure()
gspec = gridspec.GridSpec(3, 3)

top_histogram = plt.subplot(gspec[0, 1:])
side_histogram = plt.subplot(gspec[1:, 0])
lower_right = plt.subplot(gspec[1:, 1:])

# %%
Y = np.random.normal(loc=0.0, scale=1.0, size=10000)
X = np.random.random(size=10000)
lower_right.scatter(X, Y)
top_histogram.hist(X, bins=100)
s = side_histogram.hist(Y, bins=100, orientation='horizontal')

# %%
# clear the histograms and plot normed histograms
top_histogram.clear()
top_histogram.hist(X, bins=100, normed=True)
side_histogram.clear()
side_histogram.hist(Y, bins=100, orientation='horizontal', normed=True)
# flip the side histogram's x axis
side_histogram.invert_xaxis()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-109-fa90bf5b6800> in <module>
#       1 # clear the histograms and plot normed histograms
#       2 top_histogram.clear()
# ----> 3 top_histogram.hist(X, bins=100, normed=True)
#       4 side_histogram.clear()
#       5 side_histogram.hist(Y, bins=100, orientation='horizontal', normed=True)
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %%
# change axes limits
for ax in [top_histogram, lower_right]:
    ax.set_xlim(0, 1)
for ax in [side_histogram, lower_right]:
    ax.set_ylim(-5, 5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-2abf444426f1> in <module>
#       1 # change axes limits
# ----> 2 for ax in [top_histogram, lower_right]:
#       3     ax.set_xlim(0, 1)
#       4 for ax in [side_histogram, lower_right]:
#       5     ax.set_ylim(-5, 5)
#
# NameError: name 'top_histogram' is not defined

# %%
# %%HTML
# <img src='http://educationxpress.mit.edu/sites/default/files/journal/WP1-Fig13.jpg' />
# Out:
# <img src='http://educationxpress.mit.edu/sites/default/files/journal/WP1-Fig13.jpg' />

# %%
import pandas as pd
normal_sample = np.random.normal(loc=0.0, scale=1.0, size=10000)
random_sample = np.random.random(size=10000)
gamma_sample = np.random.gamma(2, size=10000)

plt.figure()
plt.hist(random_sample, bins = 1000,color='magenta')
plt.hist(gamma_sample, bins = 1000,color='red')
plt.hist(normal_sample, bins = 1000,color='pink')

df = pd.DataFrame({'normal': normal_sample})
df.describe()
df = pd.DataFrame({'normal': normal_sample, 
                   'random': random_sample, 
                   'gamma': gamma_sample})
df.describe()
# Out:
#              normal        random         gamma
# count  10000.000000  10000.000000  10000.000000
# mean      -0.012331      0.496989      2.003557
# std        0.991349      0.288332      1.413806
# min       -3.580196      0.000096      0.012157
# 25%       -0.682288      0.248005      0.955327
# 50%       -0.007247      0.497688      1.691353
# 75%        0.629596      0.747449      2.703356
# max        4.123947      0.999768     10.586736

# %%
plt.figure()
# create a boxplot of the normal data, assign the output to a variable to supress output
_ = plt.boxplot(df['normal'], whis='range')
# Out:
# <ipython-input-126-4df72a4d785b>:3: MatplotlibDeprecationWarning: Setting whis to 'range' is deprecated since 3.2 and support for it will be removed two minor releases later; set it to [0, 100] to achieve the same effect.
#   _ = plt.boxplot(df['normal'], whis='range')

# %%
# clear the current figure
plt.clf()
# plot boxplots for all three of df's columns
_ = plt.boxplot([ df['normal'], df['random'], df['gamma'] ], whis='range')
# Out:
# <ipython-input-127-27da5f4b5a50>:4: MatplotlibDeprecationWarning: Setting whis to 'range' is deprecated since 3.2 and support for it will be removed two minor releases later; set it to [0, 100] to achieve the same effect.
#   _ = plt.boxplot([ df['normal'], df['random'], df['gamma'] ], whis='range')

# %%
plt.figure()
_ = plt.hist(df['gamma'], bins=100)

# %%
import mpl_toolkits.axes_grid1.inset_locator as mpl_il

plt.figure()
plt.boxplot([ df['normal'], df['random'], df['gamma'] ], whis='range')
# overlay axis on top of another 
ax2 = mpl_il.inset_axes(plt.gca(), width='60%', height='40%', loc=2)
ax2.hist(df['gamma'], bins=100)
ax2.margins(x=0.5)
# Out:
# <ipython-input-129-4eed465a3a43>:4: MatplotlibDeprecationWarning: Setting whis to 'range' is deprecated since 3.2 and support for it will be removed two minor releases later; set it to [0, 100] to achieve the same effect.
#   plt.boxplot([ df['normal'], df['random'], df['gamma'] ], whis='range')

# %%
# switch the y axis ticks for ax2 to the right side
ax2.yaxis.tick_right()

# %%
# if `whis` argument isn't passed, boxplot defaults to showing 1.5*interquartile (IQR) whiskers with outliers
plt.figure()
_ = plt.boxplot([ df['normal'], df['random'], df['gamma'] ] )

# %%
plt.figure()

Y = np.random.normal(loc=0.0, scale=1.0, size=10000)
X = np.random.random(size=10000)
_ = plt.hist2d(X, Y, bins=25)

# %%
plt.figure()
_ = plt.hist2d(X, Y, bins=100)

# %%
plt.figure()
_ = plt.hist2d(X, Y, bins=15)

# %%
plt.figure()
_ = plt.hist2d(X, Y, bins=50)

# %%
# add a colorbar legend
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-138-ef28a2e434fb> in <module>
#       1 # add a colorbar legend
# ----> 2 plt.colorbar()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in colorbar(mappable, cax, ax, **kw)
#    2001         mappable = gci()
#    2002         if mappable is None:
# -> 2003             raise RuntimeError('No mappable was found to use for colorbar '
#    2004                                'creation. First define a mappable such as '
#    2005                                'an image (with imshow) or a contour set ('
#
# RuntimeError: No mappable was found to use for colorbar creation. First define a mappable such as an image (with imshow) or a contour set (with contourf).

# %%
import matplotlib.animation as animation

n = 100
x = np.random.randn(n)

# %%
# create the function that will do the plotting, where curr is the current frame
def update(curr):
    # check if animation is at the last frame, and if so, stop the animation a
    if curr == n: 
        a.event_source.stop()
    plt.cla()
    bins = np.arange(-4, 4, 0.5)
    plt.hist(x[:curr], bins=bins)
    plt.axis([-4,4,0,30])
    plt.gca().set_title('Sampling the Normal Distribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
    plt.annotate('n = {}'.format(curr), [2,27])

# %%
fig = plt.figure()
a = animation.FuncAnimation(fig, update, interval=1000)

# %%
plt.figure()
data = np.random.rand(10)
plt.plot(data)

def onclick(event):
    plt.cla()
    plt.plot(data)
    plt.gca().set_title('Event at pixels {},{} \nand data {},{}'.format(event.x, event.y, event.xdata, event.ydata))

# tell mpl_connect we want to pass a 'button_press_event' into onclick when the event is detected
plt.gcf().canvas.mpl_connect('key_press_event', onclick)
# Out:
# 5

# %%
from random import shuffle
origins = ['China', 'Brazil', 'India', 'USA', 'Canada', 'UK', 'Germany', 'Iraq', 'Chile', 'Mexico']

shuffle(origins)

df = pd.DataFrame({'height': np.random.rand(10),
                   'weight': np.random.rand(10),
                   'origin': origins})
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-1bb9e96622cb> in <module>
#       4 shuffle(origins)
#       5
# ----> 6 df = pd.DataFrame({'height': np.random.rand(10),
#       7                    'weight': np.random.rand(10),
#       8                    'origin': origins})
#
# NameError: name 'pd' is not defined

# %%
plt.figure()
# picker=5 means the mouse doesn't have to click directly on an event, but can be up to 5 pixels away
plt.scatter(df['height'], df['weight'], picker=5)
plt.gca().set_ylabel('Weight')
plt.gca().set_xlabel('Height')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-8ea1d0cfdfee> in <module>
#       1 plt.figure()
#       2 # picker=5 means the mouse doesn't have to click directly on an event, but can be up to 5 pixels away
# ----> 3 plt.scatter(df['height'], df['weight'], picker=5)
#       4 plt.gca().set_ylabel('Weight')
#       5 plt.gca().set_xlabel('Height')
#
# NameError: name 'df' is not defined

# %%
def onpick(event):
    origin = df.iloc[event.ind[0]]['origin']
    plt.gca().set_title('Selected item came from {}'.format(origin))

# print(origin = df.iloc[event.ind[0]]['origin'])
    
# tell mpl_connect we want to pass a 'pick_event' into onpick when the event is detected
plt.gcf().canvas.mpl_connect('pick_event', onpick)
# Out:
# 5

# %%
age=10
clas=3
marks=79.8
print('Your age is %s and class is %s. But percentage is just only %2f, why???'%(age,clas,marks))
# Out:
# Your age is 10 and class is 3. But percentage is just only 79.800000, why???
